# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def main():
    user_images = { 'bruno': (1, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\bruno.jpg'), 
     'david': (2, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\david.jpg'), 
     'eze': (3, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\eze.jpg'), 
     'francis': (4, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\francis.jpg'), 
     'kaobi': (5, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\kaobi.jpg'), 
     'lala': (6, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\lala.jpg'),
     'lotanna': (7, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\lotanna.jpg'), 
     'oyinda': (8, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\oyinda.jpg'), 
     'pese': (9, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\pese.jpg'), 
     'zion': (10, r'C:\Users\ANDERSON AYE PEPPLE\Documents\andersonpeppleCSC418\Week_2\img\zion.jpg') } 
    
    username = input("Enter username (first name): ") 
    password = int(input("Enter password (matric number): ")) 
    
    if username in user_images: 
        matric, image_path = user_images[username]
        expected_password = matric 
        if password == expected_password: 
            try:
                Option = input("Select an enhancement: \n1)Contrast\n2)Sharpeness\n3)Noise\n4)Scaling\n5)Transformation\n6)Addition\n7)Subtraction\n8)Median-Blur:\n") 
                if Option == "1": 
                    image = cv2.imread(image_path)
                    plt.subplot(1,2,1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    brightness = 5
                    contrast = 1.5
                    image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape,image.dtype), 0, brightness)
                    cv2.imwrite(f'img/{username}_contrast.jpg', image2)
                    plt.subplot(1,2,2)
                    plt.imshow(image2)
                    plt.show() 
                
                elif Option == "2":
                    image = cv2.imread(image_path)
                    plt.subplot(1,2,1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
                    sharpened_image = cv2.filter2D(image, -1, kernel)
                    cv2.imwrite(f'img/{username}_Sharpened.jpg', sharpened_image)
                    plt.subplot(1,2,2)
                    plt.imshow(sharpened_image)
                    plt.show()
                        
                elif Option == "3":
                    image = cv2.imread(image_path)
                    plt.subplot(1,2,1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    filtered_image = cv2.medianBlur(image, 15)
                    cv2.imwrite(f'img/{username}_Noiseless.jpg', filtered_image)
                    plt.subplot(1,2,2)
                    plt.imshow(filtered_image)
                    plt.show()

                elif Option == "4":
                    image = cv2.imread(image_path)
                    plt.subplot(1,2,1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    scaled_image = cv2.resize(image, None, fx=2, fy=2)
                    cv2.imwrite(f'img/{username}_Scaled.jpg', scaled_image)
                    plt.subplot(1,2,2)
                    plt.imshow(scaled_image)
                    plt.show()

                elif Option == "5":
                    image = cv2.imread(image_path)
                    plt.subplot(1,2,1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    inverse_image = 255 - image
                    cv2.imwrite(f'img/{username}_Transformed.jpg', inverse_image)
                    plt.subplot(1,2,2)
                    plt.imshow(inverse_image)
                    plt.show()
                    
                   
                elif Option == "6":
                    image = cv2.imread(image_path)
                    image2 = cv2.imread('img/sst-foyer.jpg')
                    image2 = cv2.resize(image2, (image.shape[1], image.shape[0]))
                    plt.subplot(1, 2, 1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    Added_image = cv2.addWeighted(image, 0.5, image2, 0.6, 0)
                    cv2.imwrite(f'img/{username}_Added.jpg', Added_image)
                    plt.subplot(1, 2, 2)
                    plt.imshow(Added_image)
                    plt.show()
                    
                    
                elif Option == "7":
                    image = cv2.imread(image_path)
                    image2 = cv2.imread('img/sst-foyer.jpg')
                    image2 = cv2.resize(image2, (image.shape[1], image.shape[0]))
                    plt.subplot(1, 3, 1)
                    plt.title(f'Original {username}')
                    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
                    plt.subplot(1, 3, 2)
                    plt.title('Subtracted Image')
                    subtracted_image = cv2.subtract(image, image2)
                    cv2.imwrite(f'img/{username}_Subtracted.jpg', subtracted_image)
                    plt.imshow(cv2.cvtColor(subtracted_image, cv2.COLOR_BGR2RGB))
                    plt.subplot(1, 3, 3)
                    plt.title(f'Second Image {username}')
                    plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
                    plt.show()
                    
                elif Option == "8":
                    image = cv2.imread(image_path)
                    #image2 = cv2.imread('img/sst-foyer.jpg')
                    #image2 = cv2.resize(image2, (image.shape[1], image.shape[0]))
                    plt.subplot(1, 2, 1)
                    plt.title(f'original {username}')
                    plt.imshow(image)
                    filtered_image = cv2.medianBlur(image, 15)
                    cv2.imwrite('img/Median-Blur.jpg', filtered_image)
                    plt.subplot(1, 2, 2)
                    plt.title(f'Median Blur {username}')
                    plt.imshow(filtered_image)
                    plt.show()

                
                else:
                    print("Invalid Selection")
            except Exception as e: 
                print('Error:', e)

        else:
            print("Password Not seen")

    else:
        print("Authentication failed. User not found.")
        
main()
# Out:
# Enter username (first name): bruno
# Enter password (matric number): 1
# Select an enhancement:
# 1)Contrast
# 2)Sharpeness
# 3)Noise
# 4)Scaling
# 5)Transformation
# 6)Addition
# 7)Subtraction
# 8)Median-Blur:
# 8
